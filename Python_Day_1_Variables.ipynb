# %% [markdown]
# <a href="https://colab.research.google.com/github/chamarairesh1982/LearnPython/blob/main/Python_Day_1_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Machine Learning!")
# Out:
# Hello, Machine Learning!

# %%
# Create variables
name = "Chamara"
age = 35
country = "United Kingdom"
university = "Staffordshire University"
course = "MSc Computing"

# Print the variables
print("Name:", name)
print("Age:", age)
print("Country:", country)
print("University:", university)
print("Course:", course)
# Out:
# Name: Chamara
# Age: 35
# Country: United Kingdom
# University: Staffordshire University
# Course: MSc Computing

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
country = input("Enter your country: ")
university = input("Enter your university: ")
course = input("Enter your course: ")

print("\n--- Student Information ---")
print("Name:", name)
print("Age:", age)
print("Country:", country)
print("University:", university)
print("Course:", course)
# Out:
# Enter your name: c
# Enter your age: 4
# Enter your country: uk
# Enter your university: uk
# Enter your course: it
#
# --- Student Information ---
# Name: c
# Age: 4
# Country: uk
# University: uk
# Course: it

# %%
# Create variables
project_name = "Cyber Security Platform"
project_budget = 500000
project_completed = False
project_duration_months = 12

# Print the variables
print("Project Name:", project_name)
print("Project Budget:", project_budget)
print("Project Completed:", project_completed)
print("Project Duration (Months):", project_duration_months)

print()

# Print the type of each variable
print("Type of project_name:", type(project_name))
print("Type of project_budget:", type(project_budget))
print("Type of project_completed:", type(project_completed))
print("Type of project_duration_months:", type(project_duration_months))
# Out:
# Project Name: Cyber Security Platform
# Project Budget: 500000
# Project Completed: False
# Project Duration (Months): 12
#
# Type of project_name: <class 'str'>
# Type of project_budget: <class 'int'>
# Type of project_completed: <class 'bool'>
# Type of project_duration_months: <class 'int'>

# %%
number1=15
number2=10

print(number1+number2)
print(number1-number2)
print(number1*number2)
print(number1/number2)
# Out:
# 25
# 5
# 150
# 1.5

# %%
# Create variables
length = 10
width = 5

# Calculate area and perimeter
area = length * width
perimeter = 2 * (length + width)

# Print the results
print("Length:", length)
print("Width:", width)
print("Area:", area)
print("Perimeter:", perimeter)
# Out:
# Length: 10
# Width: 5
# Area: 50
# Perimeter: 30

# %%
length = float(input("Enter the length: "))
width = float(input("Enter the width: "))

area = length * width
perimeter = 2 * (length + width)

print("Area:", area)
print("Perimeter:", perimeter)
# Out:
# Enter the length: 125
# Enter the width: 10
# Area: 1250.0
# Perimeter: 270.0

# %%
import math

# Create variable
radius = 7

# Calculate
diameter = 2 * radius
circumference = 2 * math.pi * radius
area = math.pi * radius ** 2

# Print results
print("Radius:", radius)
print("Diameter:", diameter)
print("Circumference:", circumference)
print("Area:", area)
# Out:
# Radius: 7
# Diameter: 14
# Circumference: 43.982297150257104
# Area: 153.93804002589985

# %%
import math

radius = 7

diameter = 2 * radius
circumference = 2 * math.pi * radius
area = math.pi * radius ** 2

print("Radius:", radius)
print("Diameter:", diameter)
print("Circumference:", round(circumference, 2))
print("Area:", round(area, 2))
# Out:
# Radius: 7
# Diameter: 14
# Circumference: 43.98
# Area: 153.94

# %%
# Store temperature in Celsius
celsius = 25

# Convert to Fahrenheit
fahrenheit = (celsius * 9 / 5) + 32

# Print the results
print("Temperature in Celsius:", celsius, "°C")
print("Temperature in Fahrenheit:", fahrenheit, "°F")
# Out:
# Temperature in Celsius: 25 °C
# Temperature in Fahrenheit: 77.0 °F

# %%
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9 / 5) + 32

print("Celsius:", celsius, "°C")
print("Fahrenheit:", fahrenheit, "°F")
# Out:
# Enter temperature in Celsius: 35
# Celsius: 35.0 °C
# Fahrenheit: 95.0 °F

# %%
# Create variables
a = 10
b = 20

# Before swapping
print("Before")
print("a =", a)
print("b =", b)

# Swap variables
a, b = b, a

# After swapping
print("\nAfter")
print("a =", a)
print("b =", b)
# Out:
# Before
# a = 10
# b = 20
#
# After
# a = 20
# b = 10

# %%
# Student details
student_name = "Chamara"
student_id = 1001

# Subject marks
subject1 = 85
subject2 = 90
subject3 = 88

# Calculate total and average
total = subject1 + subject2 + subject3
average = total / 3

# Display report
print("-------------------------")
print("Student Report")
print("-------------------------")
print("Name :", student_name)
print("ID :", student_id)

print()

print("Subject 1 :", subject1)
print("Subject 2 :", subject2)
print("Subject 3 :", subject3)

print()

print("Total :", total)
print("Average :", round(average, 2))
# Out:
# -------------------------
# Student Report
# -------------------------
# Name : Chamara
# ID : 1001
#
# Subject 1 : 85
# Subject 2 : 90
# Subject 3 : 88
#
# Total : 263
# Average : 87.67

# %%
x = 10
y = 5

print("x + y =", x + y)
print("x - y =", x - y)
print("x * y =", x * y)
print("x / y =", x / y)
print("x // y =", x // y)
print("x % y =", x % y)
print("x ** y =", x ** y)
# Out:
# x + y = 15
# x - y = 5
# x * y = 50
# x / y = 2.0
# x // y = 2
# x % y = 0
# x ** y = 100000

# %%
x = 11
y = 5

print(x / y)   # 2.2
print(x // y)  # 2
print(x % y)   # 1

print(17 // 4)
print(17 % 4)
print(3 ** 4)
print(20 / 8)
# Out:
# 2.2
# 2
# 1
# 4
# 1
# 81
# 2.5

# %%
# Employee details
employee_name = "Chamara"
basic_salary = 5000
bonus = 500
tax_percentage = 20

# Calculations
gross_salary = basic_salary + bonus
tax_amount = gross_salary * tax_percentage / 100
net_salary = gross_salary - tax_amount

# Salary Report
print("---------------------------------")
print("      Employee Salary Report")
print("---------------------------------")
print("Employee Name :", employee_name)
print("Basic Salary  : £", basic_salary)
print("Bonus         : £", bonus)
print("Gross Salary  : £", gross_salary)
print("Tax           :", tax_percentage, "%")
print("Tax Amount    : £", tax_amount)
print("Net Salary    : £", net_salary)
print("---------------------------------")
# Out:
# ---------------------------------
#       Employee Salary Report
# ---------------------------------
# Employee Name : Chamara
# Basic Salary  : £ 5000
# Bonus         : £ 500
# Gross Salary  : £ 5500
# Tax           : 20 %
# Tax Amount    : £ 1100.0
# Net Salary    : £ 4400.0
# ---------------------------------

# %%
# Employee details
employee_name = "Chamara"
basic_salary = 5000
bonus = 500
tax_percentage = 20

gross_salary = basic_salary + bonus
tax_amount = gross_salary * tax_percentage / 100
net_salary = gross_salary - tax_amount

print("---------------------------------")
print("      Employee Salary Report")
print("---------------------------------")
print("Employee Name :", employee_name)
print("Basic Salary  : £", basic_salary)
print("Bonus         : £", bonus)
print("Gross Salary  : £", gross_salary)
print("Tax           :", tax_percentage, "%")
print("Tax Amount    : £", round(tax_amount, 2))
print("Net Salary    : £", round(net_salary, 2))
print("---------------------------------")
# Out:
# ---------------------------------
#       Employee Salary Report
# ---------------------------------
# Employee Name : Chamara
# Basic Salary  : £ 5000
# Bonus         : £ 500
# Gross Salary  : £ 5500
# Tax           : 20 %
# Tax Amount    : £ 1100.0
# Net Salary    : £ 4400.0
# ---------------------------------
